# %% [markdown]
# # Introduction
#
# **The main content of this article will present how the AlexNet Convolutional Neural Network(CNN) architecture is implemented using TensorFlow and Keras.**
#
#
# **Here are some of the key learning objectives from this article:**
#
# 1. Introduction to neural network implementation with Keras and TensorFlow
# 2. Data preprocessing with TensorFlow
# 3. Training visualization with TensorBoard
# 4. Description of standard machine learning terms and terminologies
# 5. AlexNet Implementation
#
# AlexNet CNN is probably one of the simplest methods to approach understanding deep learning concepts and techniques.
#
# AlexNet is not a complicated architecture when it is compared with some state of the art CNN architectures that have emerged in the more recent years.
#
# AlexNet is simple enough for beginners and intermediate deep learning practitioners to pick up some good practices on model implementation techniques.

# %% [markdown]
# # Libraries

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
import os
import time

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Dataset

# %%
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

# %% [markdown]
# In order to reference the class names of the images during the visualization stage, a python list containing the classes is initialized with the variable name CLASS_NAMES.

# %%
CLASS_NAMES= ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %% [markdown]
# TensorFlow provides a suite of functions and operations that enables easy data manipulation and modification through a defined input pipeline.
#
# To be able to access these methods and procedures, it is required that we transform our dataset into an efficient data representation TensorFlow is familiar with. This is achieved using the **tf.data.Dataset API**.
#
# More specifically, **tf.data.Dataset.from_tensor_slices** method takes the train, test, and validation dataset partitions and returns a corresponding TensorFlow Dataset representation.

# %%
train_ds=tf.data.Dataset.from_tensor_slices((train_images,train_labels))
test_ds=tf.data.Dataset.from_tensor_slices((test_images,test_labels))

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Usually, preprocessing is conducted to ensure the data utilized is within an appropriate format.
#
# First, let’s visualize the images within the CIFAR-10 dataset.
#
# The CIFAR-10 images have small dimensions, which makes visualization of the actual pictures a bit difficult.

# %%
plt.figure(figsize=(30,30))
for i,(image,label) in enumerate(train_ds.take(20)):
    #print(label)
    ax=plt.subplot(5,5,i+1)
    plt.imshow(image)
    plt.title(CLASS_NAMES[label.numpy()[0]])
    plt.axis('off')

# %% [markdown]
# We’ll create a function called process_images.
#
# This function will perform all preprocessing work that we require for the data. This function is called further down the machine learning workflow.

# %%
def process_image(image,label):
    image=tf.image.per_image_standardization(image)
    image=tf.image.resize(image,(64,64))

    return image,label

# %% [markdown]
# # Data Pipeline

# %% [markdown]
# So far, we have obtained and partitioned the dataset and created a function to process the dataset. The next step is to build an input pipeline.
#
# An input/data pipeline is described as a series of functions or methods that are called consecutively one after another.
#
# Input pipelines are a chain of functions that either act upon the data or enforces an operation on the data flowing through the pipeline.

# %%
train_ds_size=tf.data.experimental.cardinality(train_ds).numpy()
test_ds_size=tf.data.experimental.cardinality(test_ds).numpy()
print('Train size:',train_ds_size)
print('Test size:',test_ds_size)
# Out:
# Train size: 50000
# Test size: 10000

# %% [markdown]
# ### For our basic input/data pipeline, we will conduct three primary operations:
#
# #### 1. Preprocessing the data within the dataset
# #### 2. Shuffle the dataset
# #### 3. Batch data within the dataset

# %%
train_ds=(train_ds
          .map(process_image)
          .shuffle(buffer_size=train_ds_size)
          .batch(batch_size=32,drop_remainder=True)
         )
test_ds=(test_ds
          .map(process_image)
          .shuffle(buffer_size=test_ds_size)
          .batch(batch_size=32,drop_remainder=True)
         )

# %% [markdown]
# # Model Implementation
#
# Within this section, we will implement the AlexNet CNN architecture from scratch.
# Through the utilization of Keras Sequential API, we can implement consecutive neural network layers within our models that are stacked against each other.
#
# Here are the types of layers the AlexNet CNN architecture is composed of, along with a brief description:
# ## Convolutional layer:
# A convolution is a mathematical term that describes a dot product multiplication between two sets of elements. Within deep learning the convolution operation acts on the filters/kernels and image data array within the convolutional layer. Therefore a convolutional layer is simply a layer the houses the convolution operation that occurs between the filters and the images passed through a convolutional neural network.
#
# ## Batch Normalisation layer:
#
# Batch Normalization is a technique that mitigates the effect of unstable gradients within a neural network through the introduction of an additional layer that performs operations on the inputs from the previous layer. The operations standardize and normalize the input values, after that the input values are transformed through scaling and shifting operations.
#
# ## MaxPooling layer:
#
# Max pooling is a variant of sub-sampling where the maximum pixel value of pixels that fall within the receptive field of a unit within a sub-sampling layer is taken as the output. The max-pooling operation below has a window of 2x2 and slides across the input data, outputting an average of the pixels within the receptive field of the kernel.
#
# ## Flatten layer:
#
# Takes an input shape and flattens the input image data into a one-dimensional array.
#
# ## Dense Layer:
#
# A dense layer has an embedded number of arbitrary units/neurons within. Each neuron is a perceptron.
#
#
# The code snippet represents the Keras implementation of the AlexNet CNN architecture.

# %%
model1=keras.models.Sequential([
    keras.layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(64,64,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3)),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10,activation='softmax')


])

# %% [markdown]
# # Training and Results
#
# To train the network, we have to compile it.
#
# The compilation processes involve specifying the following items:
#
# ## Loss function:
#
# A method that quantifies ‘how well’ a machine learning model performs. The quantification is an output(cost) based on a set of inputs, which are referred to as parameter values. The parameter values are used to estimate a prediction, and the ‘loss’ is the difference between the predictions and the actual values.
#
# ## Optimization Algorithm:
#
# An optimizer within a neural network is an algorithmic implementation that facilitates the process of gradient descent within a neural network by minimizing the loss values provided via the loss function. To reduce the loss, it is paramount the values of the weights within the network are selected appropriately.
#
# ## Learning Rate:
#
# An integral component of a neural network implementation detail as it’s a factor value that determines the level of updates that are made to the values of the weights of the network. Learning rate is a type of hyperparameter.

# %% [markdown]
# We can also provide a summary of the network to have more insight into the layer composition of the network by running the **model.summary()** function.

# %%
model1.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.optimizers.SGD(learning_rate=0.001),
    metrics=['accuracy']
)
model1.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 14, 14, 128)       46592
#
#  batch_normalization_15 (Ba  (None, 14, 14, 128)       512
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 7, 7, 128)         0
#  g2D)
#
#  conv2d_16 (Conv2D)          (None, 7, 7, 256)         819456
#
#  batch_normalization_16 (Ba  (None, 7, 7, 256)         1024
#  tchNormalization)
#
#  max_pooling2d_10 (MaxPooli  (None, 2, 2, 256)         0
#  ng2D)
#
#  conv2d_17 (Conv2D)          (None, 2, 2, 256)         590080
#
#  batch_normalization_17 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  conv2d_18 (Conv2D)          (None, 2, 2, 256)         65792
#
#  batch_normalization_18 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  conv2d_19 (Conv2D)          (None, 2, 2, 256)         65792
#
#  batch_normalization_19 (Ba  (None, 2, 2, 256)         1024
#  tchNormalization)
#
#  max_pooling2d_11 (MaxPooli  (None, 1, 1, 256)         0
#  ng2D)
#
#  flatten_3 (Flatten)         (None, 256)               0
#
#  dense_9 (Dense)             (None, 1024)              263168
#
#  dropout_6 (Dropout)         (None, 1024)              0
#
#  dense_10 (Dense)            (None, 1024)              1049600
#
#  dropout_7 (Dropout)         (None, 1024)              0
#
#  dense_11 (Dense)            (None, 10)                10250
#
# =================================================================
# Total params: 2915338 (11.12 MB)
# Trainable params: 2913034 (11.11 MB)
# Non-trainable params: 2304 (9.00 KB)
# _________________________________________________________________

# %% [markdown]
# At this point, we are ready to train the network.
#
# Training the custom AlexNet network is very simple with the Keras module enabled through TensorFlow. We simply have to call the **fit()** method and pass relevant arguments.
#
# **Epoch**: This is a numeric value that indicates the number of time a network has been exposed to all the data points within a training dataset.

# %%
# device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# model = model.to(device)
# train_ds = train_ds.to(device)

# %%
history=model1.fit(
    train_ds,
    epochs=50,
    validation_data=test_ds,
    validation_freq=1
)
# Out:
# Epoch 1/50
# 1562/1562 [==============================] - 13s 6ms/step - loss: 2.1158 - accuracy: 0.2545 - val_loss: 1.6004 - val_accuracy: 0.4255
# Epoch 2/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.7046 - accuracy: 0.3837 - val_loss: 1.4273 - val_accuracy: 0.4857
# Epoch 3/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.5248 - accuracy: 0.4473 - val_loss: 1.3220 - val_accuracy: 0.5236
# Epoch 4/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.4071 - accuracy: 0.4919 - val_loss: 1.2371 - val_accuracy: 0.5537
# Epoch 5/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1
50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1763 - accuracy: 0.9382 - val_loss: 1.4496 - val_accuracy: 0.6793
# Epoch 35/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1644 - accuracy: 0.9429 - val_loss: 1.2873 - val_accuracy: 0.6992
# Epoch 36/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1498 - accuracy: 0.9482 - val_loss: 1.3259 - val_accuracy: 0.7005
# Epoch 37/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1425 - accuracy: 0.9508 - val_loss: 1.3722 - val_accuracy: 0.7023
# Epoch 38/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1283 - accuracy: 0.9564 - val_loss: 1.3631 - val_accuracy: 0.7024
# Epoch 39/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1243 - accuracy: 0.9572 - val_loss: 1.4155 - val_accuracy: 0.6983
# Epoch 40/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1141 - accuracy: 0.9614 - val_loss: 1.4222 - val_accuracy: 0.6999
# Epoch 41/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1089 - accuracy: 0.9626 - val_loss: 1.4181 - val_accuracy: 0.7020
# Epoch 42/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0985 - accuracy: 0.9667 - val_loss: 1.4911 - val_accuracy: 0.6967
# Epoch 43/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0967 - accuracy: 0.9671 - val_loss: 1.4872 - val_accuracy: 0.7044
# Epoch 44/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0889 - accuracy: 0.9698 - val_loss: 1.4704 - val_accuracy: 0.7055
# Epoch 45/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0869 - accuracy: 0.9705 - val_loss: 1.4757 - val_accuracy: 0.7030
# Epoch 46/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0804 - accuracy: 0.9722 - val_loss: 1.4808 - val_accuracy: 0.7077
# Epoch 47/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0774 - accuracy: 0.9733 - val_loss: 1.5338 - val_accuracy: 0.7050
# Epoch 48/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0696 - accuracy: 0.9764 - val_loss: 1.5208 - val_accuracy: 0.7129
# Epoch 49/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0701 - accuracy: 0.9766 - val_loss: 1.5472 - val_accuracy: 0.7033
# Epoch 50/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0661 - accuracy: 0.9785 - val_loss: 1.5456 - val_accuracy: 0.7079

# %%
model1.history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Now we will visualize the training over the different epochs .

# %%
f,ax=plt.subplots(2,1,figsize=(10,10))

#Assigning the first subplot to graph training loss and validation loss
ax[0].plot(model1.history.history['loss'],color='b',label='Training Loss')
ax[0].plot(model1.history.history['val_loss'],color='r',label='Validation Loss')

#Plotting the training accuracy and validation accuracy
ax[1].plot(model1.history.history['accuracy'],color='b',label='Training  Accuracy')
ax[1].plot(model1.history.history['val_accuracy'],color='r',label='Validation Accuracy')

plt.legend()

# %%
print('Accuracy Score = ',np.max(history.history['val_accuracy']))
# Out:
# Accuracy Score =  0.7129406929016113

# %%
model2=keras.models.Sequential([
    keras.layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(64,64,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(1, 1)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(1, 1)),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(1, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10,activation='softmax')


])

# %%
model2.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.optimizers.SGD(learning_rate=0.001),
    metrics=['accuracy']
)
model2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_20 (Conv2D)          (None, 14, 14, 128)       46592
#
#  batch_normalization_20 (Ba  (None, 14, 14, 128)       512
#  tchNormalization)
#
#  max_pooling2d_12 (MaxPooli  (None, 13, 13, 128)       0
#  ng2D)
#
#  conv2d_21 (Conv2D)          (None, 13, 13, 256)       819456
#
#  batch_normalization_21 (Ba  (None, 13, 13, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_13 (MaxPooli  (None, 11, 11, 256)       0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 11, 11, 256)       590080
#
#  batch_normalization_22 (Ba  (None, 11, 11, 256)       1024
#  tchNormalization)
#
#  conv2d_23 (Conv2D)          (None, 11, 11, 256)       65792
#
#  batch_normalization_23 (Ba  (None, 11, 11, 256)       1024
#  tchNormalization)
#
#  conv2d_24 (Conv2D)          (None, 11, 11, 256)       65792
#
#  batch_normalization_24 (Ba  (None, 11, 11, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_14 (MaxPooli  (None, 10, 10, 256)       0
#  ng2D)
#
#  flatten_4 (Flatten)         (None, 25600)             0
#
#  dense_12 (Dense)            (None, 1024)              26215424
#
#  dropout_8 (Dropout)         (None, 1024)              0
#
#  dense_13 (Dense)            (None, 1024)              1049600
#
#  dropout_9 (Dropout)         (None, 1024)              0
#
#  dense_14 (Dense)            (None, 10)                10250
#
# =================================================================
# Total params: 28867594 (110.12 MB)
# Trainable params: 28865290 (110.11 MB)
# Non-trainable params: 2304 (9.00 KB)
# _________________________________________________________________

# %%
history=model2.fit(
    train_ds,
    epochs=50,
    validation_data=test_ds,
    validation_freq=1
)
# Out:
# Epoch 1/50
# 1562/1562 [==============================] - 13s 6ms/step - loss: 2.0333 - accuracy: 0.3121 - val_loss: 1.5017 - val_accuracy: 0.4625
# Epoch 2/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.6112 - accuracy: 0.4263 - val_loss: 1.3469 - val_accuracy: 0.5205
# Epoch 3/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.4450 - accuracy: 0.4883 - val_loss: 1.2384 - val_accuracy: 0.5601
# Epoch 4/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1
50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2411 - accuracy: 0.9176 - val_loss: 0.8073 - val_accuracy: 0.7680
# Epoch 34/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2286 - accuracy: 0.9214 - val_loss: 0.8296 - val_accuracy: 0.7687
# Epoch 35/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2142 - accuracy: 0.9262 - val_loss: 0.8131 - val_accuracy: 0.7697
# Epoch 36/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2020 - accuracy: 0.9319 - val_loss: 0.8033 - val_accuracy: 0.7825
# Epoch 37/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1889 - accuracy: 0.9364 - val_loss: 0.8280 - val_accuracy: 0.7774
# Epoch 38/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1788 - accuracy: 0.9398 - val_loss: 0.8486 - val_accuracy: 0.7771
# Epoch 39/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1670 - accuracy: 0.9434 - val_loss: 0.8304 - val_accuracy: 0.7803
# Epoch 40/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1580 - accuracy: 0.9472 - val_loss: 0.8714 - val_accuracy: 0.7770
# Epoch 41/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1500 - accuracy: 0.9501 - val_loss: 0.8734 - val_accuracy: 0.7795
# Epoch 42/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1446 - accuracy: 0.9519 - val_loss: 0.9400 - val_accuracy: 0.7708
# Epoch 43/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1327 - accuracy: 0.9547 - val_loss: 0.8798 - val_accuracy: 0.7825
# Epoch 44/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1250 - accuracy: 0.9592 - val_loss: 0.8942 - val_accuracy: 0.7844
# Epoch 45/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1151 - accuracy: 0.9620 - val_loss: 0.9205 - val_accuracy: 0.7747
# Epoch 46/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1159 - accuracy: 0.9617 - val_loss: 0.9193 - val_accuracy: 0.7809
# Epoch 47/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1084 - accuracy: 0.9643 - val_loss: 0.9088 - val_accuracy: 0.7834
# Epoch 48/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1029 - accuracy: 0.9661 - val_loss: 0.9369 - val_accuracy: 0.7761
# Epoch 49/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0951 - accuracy: 0.9685 - val_loss: 0.9055 - val_accuracy: 0.7856
# Epoch 50/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0897 - accuracy: 0.9712 - val_loss: 0.9833 - val_accuracy: 0.7727

# %%
f,ax=plt.subplots(2,1,figsize=(10,10))

#Assigning the first subplot to graph training loss and validation loss
ax[0].plot(model2.history.history['loss'],color='b',label='Training Loss')
ax[0].plot(model2.history.history['val_loss'],color='r',label='Validation Loss')
ax[0].set_title('Loss')

#Plotting the training accuracy and validation accuracy
ax[1].plot(model1.history.history['accuracy'],color='#00008B',label='Training  Accuracy')
ax[1].plot(model1.history.history['val_accuracy'],color='b',label='Validation Accuracy')
ax[1].plot(model2.history.history['accuracy'],color='#8B0000',label='Overlapping Training  Accuracy')
ax[1].plot(model2.history.history['val_accuracy'],color='r',label='Overlapping Validation Accuracy')
ax[1].set_title('Accuracy')
plt.legend()

# %%
print('Accuracy Score = ',np.max(history.history['val_accuracy']))
# Out:
# Accuracy Score =  0.7855569124221802

# %%
model3=keras.models.Sequential([
    keras.layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='tanh', input_shape=(64,64,3)),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(1, 1)),
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='tanh', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(3,3), strides=(1, 1)),
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='tanh', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='tanh', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='tanh', padding="same"),
    keras.layers.BatchNormalization(),
    keras.layers.MaxPool2D(pool_size=(2,2), strides=(1, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(1024,activation='tanh'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='tanh'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10,activation='softmax')


])

# %%
model3.compile(
    loss='sparse_categorical_crossentropy',
    optimizer=tf.optimizers.SGD(learning_rate=0.001),
    metrics=['accuracy']
)
model3.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_25 (Conv2D)          (None, 14, 14, 128)       46592
#
#  batch_normalization_25 (Ba  (None, 14, 14, 128)       512
#  tchNormalization)
#
#  max_pooling2d_15 (MaxPooli  (None, 13, 13, 128)       0
#  ng2D)
#
#  conv2d_26 (Conv2D)          (None, 13, 13, 256)       819456
#
#  batch_normalization_26 (Ba  (None, 13, 13, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_16 (MaxPooli  (None, 11, 11, 256)       0
#  ng2D)
#
#  conv2d_27 (Conv2D)          (None, 11, 11, 256)       590080
#
#  batch_normalization_27 (Ba  (None, 11, 11, 256)       1024
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 11, 11, 256)       65792
#
#  batch_normalization_28 (Ba  (None, 11, 11, 256)       1024
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 11, 11, 256)       65792
#
#  batch_normalization_29 (Ba  (None, 11, 11, 256)       1024
#  tchNormalization)
#
#  max_pooling2d_17 (MaxPooli  (None, 10, 10, 256)       0
#  ng2D)
#
#  flatten_5 (Flatten)         (None, 25600)             0
#
#  dense_15 (Dense)            (None, 1024)              26215424
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_16 (Dense)            (None, 1024)              1049600
#
#  dropout_11 (Dropout)        (None, 1024)              0
#
#  dense_17 (Dense)            (None, 10)                10250
#
# =================================================================
# Total params: 28867594 (110.12 MB)
# Trainable params: 28865290 (110.11 MB)
# Non-trainable params: 2304 (9.00 KB)
# _________________________________________________________________

# %%
history=model3.fit(
    train_ds,
    epochs=50,
    validation_data=test_ds,
    validation_freq=1
)
# Out:
# Epoch 1/50
# 1562/1562 [==============================] - 13s 7ms/step - loss: 1.9418 - accuracy: 0.3519 - val_loss: 1.3955 - val_accuracy: 0.5096
# Epoch 2/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.5688 - accuracy: 0.4698 - val_loss: 1.2936 - val_accuracy: 0.5562
# Epoch 3/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.3938 - accuracy: 0.5239 - val_loss: 1.1842 - val_accuracy: 0.6027
# Epoch 4/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.2618 - accuracy: 0.5654 - val_loss: 1.1074 - val_accuracy: 0.6256
# Epoch 5/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.1683 - accuracy: 0.5975 - val_loss: 1.0491 - val_accuracy: 0.6442
# Epoch 6/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.0775 - accuracy: 0.6241 - val_loss: 1.0160 - val_accuracy: 0.6532
# Epoch 7/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 1.0241 - accuracy: 0.6434 - val_loss: 0.9559 - val_accuracy: 0.6792
# Epoch 8/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.9595 - accuracy: 0.6664 - val_loss: 0.9391 - val_accuracy: 0.6846
# Epoch 9/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.9065 - accuracy: 0.6842 - val_loss: 0.9553 - val_accuracy: 0.6884
# Epoch 10/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.8607 - accuracy: 0.7010 - val_loss: 0.9685 - val_accuracy: 0.6818
# Epoch 11/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.8234 - accuracy: 0.7144 - val_loss: 0.8413 - val_accuracy: 0.7213
# Epoch 12/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.7813 - accuracy: 0.7298 - val_loss: 0.8475 - val_accuracy: 0.7195
# Epoch 13/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.7448 - accuracy: 0.7404 - val_loss: 0.8658 - val_accuracy: 0.7171
# Epoch 14/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.7190 - accuracy: 0.7494 - val_loss: 0.8097 - val_accuracy: 0.7360
# Epoch 15/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.6817 - accuracy: 0.7637 - val_loss: 0.8351 - val_accuracy: 0.7282
# Epoch 16/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.6510 - accuracy: 0.7728 - val_loss: 0.8368 - val_accuracy: 0.7248
# Epoch 17/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.6212 - accuracy: 0.7835 - val_loss: 0.8337 - val_accuracy: 0.7381
# Epoch 18/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.5944 - accuracy: 0.7930 - val_loss: 0.8315 - val_accuracy: 0.7346
# Epoch 19/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.5692 - accuracy: 0.8019 - val_loss: 0.8263 - val_accuracy: 0.7417
# Epoch 20/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.5384 - accuracy: 0.8108 - val_loss: 0.8636 - val_accuracy: 0.7311
# Epoch 21/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.5144 - accuracy: 0.8207 - val_loss: 0.8343 - val_accuracy: 0.7424
# Epoch 22/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.4918 - accuracy: 0.8272 - val_loss: 0.8271 - val_accuracy: 0.7457
# Epoch 23/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.4624 - accuracy: 0.8391 - val_loss: 0.8227 - val_accuracy: 0.7482
# Epoch 24/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.4469 - accuracy: 0.8432 - val_loss: 0.8318 - val_accuracy: 0.7497
# Epoch 25/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.4251 - accuracy: 0.8520 - val_loss: 0.8460 - val_accuracy: 0.7481
# Epoch 26/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.3966 - accuracy: 0.8636 - val_loss: 0.8164 - val_accuracy: 0.7572
# Epoch 27/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.3697 - accuracy: 0.8709 - val_loss: 0.8901 - val_accuracy: 0.7434
# Epoch 28/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.3548 - accuracy: 0.8762 - val_loss: 0.8990 - val_accuracy: 0.7437
# Epoch 29/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.3324 - accuracy: 0.8843 - val_loss: 0.8344 - val_accuracy: 0.7625
# Epoch 30/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.3170 - accuracy: 0.8896 - val_loss: 0.9113 - val_accuracy: 0.7509
# Epoch 31/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2953 - accuracy: 0.8978 - val_loss: 1.0042 - val_accuracy: 0.7333
# Epoch 32/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2825 - accuracy: 0.9019 - val_loss: 0.8843 - val_accuracy: 0.7560
# Epoch 33/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2619 - accuracy: 0.9089 - val_loss: 0.9627 - val_accuracy: 0.7476
# Epoch 34/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2464 - accuracy: 0.9155 - val_loss: 0.9205 - val_accuracy: 0.7541
# Epoch 35/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2296 - accuracy: 0.9208 - val_loss: 0.9862 - val_accuracy: 0.7474
# Epoch 36/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2171 - accuracy: 0.9255 - val_loss: 0.9331 - val_accuracy: 0.7570
# Epoch 37/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.2014 - accuracy: 0.9311 - val_loss: 1.0651 - val_accuracy: 0.7381
# Epoch 38/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1854 - accuracy: 0.9367 - val_loss: 1.0181 - val_accuracy: 0.7499
# Epoch 39/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1670 - accuracy: 0.9435 - val_loss: 1.0876 - val_accuracy: 0.7384
# Epoch 40/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1589 - accuracy: 0.9469 - val_loss: 1.0458 - val_accuracy: 0.7487
# Epoch 41/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1482 - accuracy: 0.9506 - val_loss: 1.0147 - val_accuracy: 0.7573
# Epoch 42/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1325 - accuracy: 0.9562 - val_loss: 1.0492 - val_accuracy: 0.7528
# Epoch 43/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1271 - accuracy: 0.9577 - val_loss: 1.0607 - val_accuracy: 0.7542
# Epoch 44/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1210 - accuracy: 0.9600 - val_loss: 1.1923 - val_accuracy: 0.7417
# Epoch 45/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1146 - accuracy: 0.9615 - val_loss: 1.0788 - val_accuracy: 0.7592
# Epoch 46/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.1038 - accuracy: 0.9659 - val_loss: 1.0942 - val_accuracy: 0.7617
# Epoch 47/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0965 - accuracy: 0.9697 - val_loss: 1.1272 - val_accuracy: 0.7581
# Epoch 48/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0900 - accuracy: 0.9714 - val_loss: 1.1450 - val_accuracy: 0.7530
# Epoch 49/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0847 - accuracy: 0.9727 - val_loss: 1.0994 - val_accuracy: 0.7605
# Epoch 50/50
# 1562/1562 [==============================] - 11s 6ms/step - loss: 0.0806 - accuracy: 0.9738 - val_loss: 1.1697 - val_accuracy: 0.7561

# %%
#Assigning the first subplot to graph training loss and validation loss
plt.plot(model2.history.history['loss'],color='b',label='ReLU Loss')
plt.plot(model3.history.history['loss'],color='r',label='tanh Loss')


plt.legend()
print('Accuracy Score = ',np.max(history.history['val_accuracy']))
# Out:
# Accuracy Score =  0.7625200152397156
